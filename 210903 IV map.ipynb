# %%
# %matplotlib nbagg
import sys
sys.path.append(r'C:\Users\Bluefors\Dropbox (Moler group)\TeamBFLD\software\python\scanning-squid\scanning-squid')
import utils
import numpy as np
from microscope.susceptometer import SusceptometerMicroscope
import logging
import time

# %%
#Change log_name
config_file = 'config_susceptometer.json'
m = SusceptometerMicroscope(config_file, 'LT', log_name='TTG sample9')
# Out:
# INFO:2021-09-14_20:50:58:microscope:Logging started.
# INFO:2021-09-14_20:50:58:microscope:Initializing microscope object using file config_susceptometer.json.
# INFO:2021-09-14_20:50:58:atto:Initializing ANC300 controller.
# INFO:2021-09-14_20:51:00:microscope:Attocube controller successfully added to microscope.
# INFO:2021-09-14_20:51:00:microscope:Lakeshore 372 successfully added to microscope.
# INFO:2021-09-14_20:51:00:microscope:Keithley 2400 successfully added to microscope.
# Connected to: ver.
# Connected to: LSCI 372 (serial:LSA17DZ, firmware:1.3) in 0.08s
# Connected to: KEITHLEY INSTRUMENTS INC. 2440 (serial:0987762, firmware:C26   Jul  1 2003 13:56:08/A02  /B/A) in 0.02s
# Connected to: KEITHLEY INSTRUMENTS INC. 2410 (serial:1370790, firmware:C32   Oct  4 2010 14:20:11/A02  /J/K) in 0.02s
# INFO:2021-09-14_20:51:00:microscope:Keithley 2410 successfully added to microscope.
# INFO:2021-09-14_20:51:00:scanner:Moved scanner from [-0.002, -0.001, -0.0] V to [-0.001, -0.001, -0.001] V.
# INFO:2021-09-14_20:51:00:microscope:Scanner successfully added to microscope.
# INFO:2021-09-14_20:51:00:microscope:Susceptometer(SQUID) successfully added to microscope.
# C:\Users\Bluefors\Anaconda3\envs\scanning-squid\lib\site-packages\qcodes\instrument\parameter.py:211: UserWarning: Wrapping get method, original get method will not be directly accessible. It is recommended to define get_raw in your subclass instead.
#   warnings.warn('Wrapping get method, original get method will not '
# Connected to: Stanford_Research_Systems SR830 (serial:s/n37680, firmware:ver1.07) in 0.04s
# INFO:2021-09-14_20:51:01:microscope:SUSC_lockin successfully added to microscope.
# Connected to: Stanford_Research_Systems SR830 (serial:s/n37721, firmware:ver1.07) in 0.05s
# INFO:2021-09-14_20:51:01:microscope:CAP_lockin successfully added to microscope.

# %%
#Folder must have "config_measurements_susc.json"
log = logging.getLogger()
measurements = utils.load_json_ordered('config_measurements_susc.json')

# %%
m.ke2410.volt(0)

# %%
m.scanner.apply_gate(0)
# Out:
# INFO:2021-09-13_17:15:20:scanner:Changed gate from 9.998 V to -0.001 V.

# %%
m.gated_IV(measurements["gated_IV"])
# Out:
# INFO:2021-09-13_17:38:25:microscope:Setting amplitude on SUSC_lockin to 0.05 V.
# INFO:2021-09-13_17:38:25:microscope:Setting frequency on SUSC_lockin to 17.78 Hz.
# <img src="data:image/png;base64,..." width="640">
# WARNING:2021-09-13_17:38:28:microscope:start ramping keithley at 4.0 V/s.
# WARNING:2021-09-13_17:38:31:microscope:gate ramp completed
# INFO:2021-09-13_17:38:31:microscope:Starting gating sample
# Started at 2021-09-13 17:38:31
# WARNING:2021-09-13_17:39:52:microscope:gating interrupted by user. setting gate back to 0
# WARNING:2021-09-13_17:39:52:microscope:start ramping keithley at 4.0 V/s.
# DataSet:
#    location = 'data/2021-09-13/#067_gated_IV_17-38-31'
#    <Type>   | <array_id>      | <array.name> | <array.shape>
#    Setpoint | ke2410_volt_set | volt         | (201,)
#    Measured | daq_ai_voltage  | voltage      | (201, 1, 1)
# Finished at 2021-09-13 17:39:52
# WARNING:2021-09-13_17:39:53:microscope:gate ramp completed
# INFO:2021-09-13_17:39:53:microscope:Measurement aborted by user. DataSet saved to data/2021-09-13/#067_gated_IV_17-38-31.
# WARNING:2021-09-13_17:39:54:microscope:start ramping keithley at 4.0 V/s.
# WARNING:2021-09-13_17:39:54:microscope:gate ramp completed
# (DataSet:
#     location = 'data/2021-09-13/#067_gated_IV_17-38-31'
#     <Type>   | <array_id>      | <array.name> | <array.shape>
#     Setpoint | ke2410_volt_set | volt         | (201,)
#     Measured | daq_ai_voltage  | voltage      | (201, 1, 1),
#  <plots.gatePlot at 0x19bf088b160>)

# %%
# sample lead 15 16 
# full map
m.double_gated_IV(measurements["double_gated_IV"])
# Out:
# INFO:2021-09-13_17:58:44:microscope:Setting amplitude on SUSC_lockin to 0.05 V.
# INFO:2021-09-13_17:58:44:microscope:Setting frequency on SUSC_lockin to 17.77 Hz.
# INFO:2021-09-13_17:58:47:microscope:Removed daq_ai from microscope.
# <img src="data:image/png;base64,..." width="1000">
# WARNING:2021-09-13_17:58:48:microscope:start ramping keithley at 4.0 V/s.
# WARNING:2021-09-13_17:58:51:microscope:gate ramp completed
# INFO:2021-09-13_17:58:51:microscope:Starting gating sample
# Started at 2021-09-13 17:58:51
# WARNING:2021-09-13_23:42:40:microscope:start ramping keithley at 4.0 V/s.
# DataSet:
#    location = 'data/2021-09-13/#070_double_gated_IV_17-58-51'
#    <Type>   | <array_id>      | <array.name> | <array.shape>
#    Setpoint | ke2410_volt_set | volt         | (201,)
#    Measured | daq_ai_voltage  | voltage      | (201, 3, 201)
# Finished at 2021-09-13 23:42:40
# WARNING:2021-09-13_23:42:43:microscope:gate ramp completed
# WARNING:2021-09-13_23:42:43:scanner:Setting ramp speed to maximum allowed: 1.0 V/s.
# INFO:2021-09-13_23:42:46:scanner:Changed gate from 9.998 V to -0.001 V.
# (DataSet:
#     location = 'data/2021-09-13/#070_double_gated_IV_17-58-51'
#     <Type>   | <array_id>      | <array.name> | <array.shape>
#     Setpoint | ke2410_volt_set | volt         | (201,)
#     Measured | daq_ai_voltage  | voltage      | (201, 3, 201),
#  <plots.DoubleGatedPlot at 0x1602a05bc88>)
