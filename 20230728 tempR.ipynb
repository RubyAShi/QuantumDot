# %%
# %matplotlib nbagg
import sys
sys.path.append(r'C:\Users\BF4K\Dropbox (Moler group)\TeamBF4K\software\scanning-squid\scanning-squid')
import utils
import numpy as np
from microscope.susceptometer import SusceptometerMicroscope
import logging
import time
from scipy import io
import matplotlib.pyplot as plt
from IPython.display import Image

# %%
config_file = 'config_susceptometer.json'
m = SusceptometerMicroscope(config_file, 'LT', log_name='Nd nickelate on LAST')
# Out:
# INFO:2023-08-02_00:09:53:microscope:Logging started.
# INFO:2023-08-02_00:09:53:microscope:Initializing microscope object using file config_susceptometer.json.
# INFO:2023-08-02_00:09:53:atto:Initializing ANC300 controller.
# INFO:2023-08-02_00:09:54:microscope:Attocube controller successfully added to microscope.
# INFO:2023-08-02_00:09:54:microscope:Lakeshore 335 successfully added to microscope.
# Connected to: ver.
# Connected to: LSCI 335 (serial:335A175/#######, firmware:1.2) in 0.12s
# Connected to: LSCI 340 (serial:340862, firmware:021901) in 0.08s
# INFO:2023-08-02_00:09:55:microscope:Lakeshore 340 successfully added to microscope.
# INFO:2023-08-02_00:09:55:scanner:Moved scanner from [-0.001, 0.0, -0.001] V to [-0.001, 0.0, -0.0] V.
# INFO:2023-08-02_00:09:55:microscope:Scanner successfully added to microscope.
# INFO:2023-08-02_00:09:55:microscope:Susceptometer(SQUID) successfully added to microscope.
# ...

# %%
m.ls335.A.temperature()
# Out:
# 11.0

# %%
m.ls335.set_temperature(3)

# %%
measurements = utils.load_json_ordered('config_measurements_susc.json')
m.measure_R_v_T(measurements["Four_prob"])
# Out:
# INFO:2023-08-01_23:46:26:microscope:Setting amplitude on SUSC_lockin to 1 V.
# INFO:2023-08-01_23:46:26:microscope:Setting frequency on SUSC_lockin to 887 Hz.
# data acquization time interval is(s)
# 1.5
# <img src="data:image/png;base64,..." width="638.888905813665">
# INFO:2023-08-01_23:46:29:microscope:Starting voltage sweep:
# Started at 2023-08-01 23:46:29
# DataSet:
#    location = 'data/2023-08-01/#011_RvT_23-46-29'
#    <Type>   | <array_id>                | <array.name>    | <array.shape>
#    Setpoint | ls335_set_temperature_set | set_temperature | (441,)
#    Measured | daq_ai_voltage            | voltage         | (441, 1, 1)
# Finished at 2023-08-01 23:58:50
# (DataSet:
#     location = 'data/2023-08-01/#011_RvT_23-46-29'
#     <Type>   | <array_id>                | <array.name>    | <array.shape>
#     Setpoint | ls335_set_temperature_set | set_temperature | (441,)
#     Measured | daq_ai_voltage            | voltage         | (441, 1, 1),
# ...

# %%
m.SUSC_lockin.amplitude(.004)
